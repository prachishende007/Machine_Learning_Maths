# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
from scipy.stats import skewnorm

# %%
a = -10   #skewness parameter if + its right skewedand if - its left skewed
size = 10000
data = np.random.normal(loc = 0, scale= 1, size = 10000)
data2 = skewnorm.rvs(a, size = size)
fig, axs = plt.subplots(2, 1, figsize = (10, 8))

#plot data on each subplot
axs[0].hist(data)
axs[0].set_title('Normal')

axs[1].hist(data2)
axs[1].set_title('Skewed')
plt.show()

# %%
sorted_data = np.sort(data)
sorted_data2 = np.sort(data2)

#Calculate the percentiles
n = len(sorted_data)
percentiles = (np.arange(1, n + 1) - 0.5) / n * 100

#Plot the QQ plot
fig, ax = plt.subplots(1, 2, figsize =(15, 5))
ax[0].plot(sorted_data, percentiles, marker = 'o', linestyle = 'none')
ax[1].plot(sorted_data2, percentiles, marker = 'o', linestyle = 'none')
plt.grid(True)
plt.show()

# %%
data
# Out:
# array([ 1.17107397, -0.44022657,  0.89591257, ...,  0.1738004 ,
#        -1.31616105,  0.58101411], shape=(10000,))

# %%
data = np.random.normal(loc = 0, scale = 1, size = 1000)
fig, ax = plt.subplots()
stats.probplot(data, dist = 'norm', plot = ax)
ax.get_lines()[1].set_color('red')
ax.get_lines()[1].set_color('red')
ax.get_lines()[1].set_linewidth(2)

plt.title('qq plot')
plt.xlabel('THEOROTICAL QUANTILES')
plt.ylabel('SAMPLE QUANTILES')
plt.grid(True)
plt.show()

# %%
data2 = skewnorm.rvs(a, size = size)
fig, ax = plt.subplots()
stats.probplot(data2, dist = 'norm', plot = ax)
ax.get_lines()[1].set_color('red')
ax.get_lines()[1].set_linestyle('dashed')
ax.get_lines()[1].set_linewidth(2)

plt.title('QQ plot')
plt.xlabel('THEORETICAL QUANTILES')
plt.ylabel('SAMPLE QUANTILES')
plt.grid(True)
plt.show()
